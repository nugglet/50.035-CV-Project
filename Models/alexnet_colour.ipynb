# %%
# !pip3 install --upgrade torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ...

# %%
import models #import from models.py

# Global Vars
path = '../Datasets/ImageNet-Sketch/sketch'

# Number of epochs in the paper is 100 but we decide to go for 50 epochs
args = { 'val_data_path': '../Datasets/Custom/Imagenet-Sketch',
        'batch_size': 32,
        'num_epochs' : 50,
        'print_every': 500
}

# %%
# AlexNet Color Distortion
alex_model_colour = models.CNNClassifier('alexnet', path, 'alex_colour', colour_distort=True, **args)
# model name = alexnet (AlexNet)
# training data path located in path global var
# alias = alex_colour - for color distortion
# color_distortion = True
alex_model_colour.train()
# Out:
# CUDA available
# GeForce MX130
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# Using cache found in C:\Users\USER'/.cache\torch\hub\pytorch_vision_v0.10.0
# => no checkpoint found at 'None'
# Created model: alexnet with pre-processing filter.
# Epoch 0/49
# ----------
# Epoch: [0][   0/1273]	Time 28.994 (28.994)	Data 17.711 (17.711)	Loss 0.0000e+00 (0.0000e+00)	Acc@1   0.00 (  0.00)	Acc@3   0.00 (  0.00)
# Epoch: [0][ 500/1273]	Time  0.034 ( 1.039)	Data  0.000 ( 0.786)	Loss nan (nan)	Acc@1   0.00 (  0.15)	Acc@3   0.00 (  0.35)
# Epoch: [0][1000/1273]	Time  0.042 ( 1.048)	Data  0.000 ( 0.800)	Loss nan (nan)	Acc@1   0.00 (  0.14)	Acc@3   0.00 (  0.36)
# Test: [  0/319]	Time 42.336 (42.336)	Loss nan (nan)	Acc@1   0.00 (  0.00)	Acc@3   3.12 (  3.12)
#  *   Acc@1 0.088 Acc@3 0.236
# Epoch 0: completed in 29.63 minutes
# Epoch 1/49
# ----------
# ...

# %%
import torch
import torchvision

torch.cuda.is_available()

# %%
# Validation Set
alex_model_colour.validate()
# Out:
# Validate: [0/4]	Time  4.750 ( 4.750)	Loss nan (nan)	Acc@1   0.00 (  0.00)	Acc@3  40.62 ( 40.62)
#  *   Acc@1 0.833 Acc@3 42.500
# tensor(0.8333, device='cuda:0')

# %%
# Load Model if needed and validate on validation set
trained_model = models.CNNClassifier('alexnet', path, 'temp', resume='./checkpoints/alex_colour_model_best.pth.tar', colour_distort=True, **args)
trained_model.validate()
